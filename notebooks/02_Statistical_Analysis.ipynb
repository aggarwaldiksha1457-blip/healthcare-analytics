# %% [markdown]
# # Statistical Analysis
#
# This notebook performs descriptive statistics, hypothesis testing, and correlation analysis on the healthcare dataset.

# %%
import sys; sys.path.insert(0, '../')
from src.statistical_analysis import run_statistical_analysis

# Run all statistical tests
run_statistical_analysis()
# Out:
# ══════════════════════════════════════════════════════════════════════
#   DESCRIPTIVE STATISTICS
# ══════════════════════════════════════════════════════════════════════
#
# ── Full describe() ──
#                Name           Age Gender Blood Type Medical Condition           Date of Admission         Doctor   Hospital Insurance Provider  Billing Amount   Room Number Admission Type              Discharge Date Medication Test Results  Days_in_Hospital Age_Group Billing_Category Month_of_Admission  Year_of_Admission  Is_Emergency   Is_Abnormal    Risk_Score    Gender_Enc  Blood Type_Enc  Medical Condition_Enc  Admission Type_Enc  Medication_Enc  Test Results_Enc  Insurance Provider_Enc  Hospital_Enc    Doctor_Enc  Age_Group_Enc  Billing_Category_Enc  Month_of_Admission_Enc
# count         54966  54966.000000  54966      54966             54966                       54966          54966      54966              54966    54966.000000  54966.000000          54966                       54966      54966        54966      54966.000000     54966            54966              54966       54966.000000  54966.000000  54966.000000  54966.000000  54966.000000    54966.000000           54966.000000        54966.000000    54966.000000      54966.000000            54966.000000  54966.000000  54966.000000   54966.000000          54966.000000            54966.000000
# unique        49992           NaN      2          8                 6                         NaN          40341      39876                  5             NaN           NaN              3                         NaN          5            3               NaN         5                3                 12                NaN           NaN           NaN           NaN           NaN             NaN                    NaN                 NaN             NaN               NaN                     NaN           NaN           NaN            NaN                   NaN                     NaN
# top     DAvId muNoZ           NaN   Male         A-         Arthritis                         NaN  Michael Smith  LLC Smith              Cigna             NaN           NaN       Elective                         NaN    Lipitor     Abnormal               NaN    Senior             High             August                NaN           NaN           NaN           NaN           NaN             NaN                    NaN                 NaN             NaN               NaN                     NaN           NaN           NaN            NaN                   NaN                     NaN
# freq              3           NaN  27496       6898              9218                         NaN             27         44              11139             NaN           NaN          18473                         NaN      11038        18437               NaN     16245            22460               4785                NaN           NaN           NaN           NaN           NaN             NaN                    NaN                 NaN             NaN               NaN                     NaN           NaN           NaN            NaN                   NaN                     NaN
# mean            NaN     51.535185    NaN        NaN               NaN  2021-11-01 17:35:29.505512            NaN        NaN                NaN    25544.306284    301.124404            NaN  2021-11-17 05:34:28.202161        NaN          NaN         15.499290       NaN              NaN                NaN        2021.336499      0.329331      0.335426      2.073555      0.500237        3.492013               2.498945            0.998508        1.997926          0.998072                2.008569  19662.619710  20187.797820       2.222374              0.998235                5.495725
#
# ── Top 5 Patients by Billing ──
#                    Name  Age Medical Condition  Billing Amount
# 36349     tOdd CARrILlO   51      Hypertension    52764.276736
# 34613       kARen klInE   79            Cancer    52373.032374
# 51183       kARen klInE   74            Cancer    52373.032374
# 5735     DAVId SanDOvaL   22      Hypertension    52271.663747
# 7088   kathRYN GoNzales   18          Diabetes    52211.852966
#
# ══════════════════════════════════════════════════════════════════════
#   HYPOTHESIS TESTS
# ══════════════════════════════════════════════════════════════════════
# [T-TEST] Emergency vs Non-Emergency Billing
#   t-stat=-0.4514  p=0.6517
#   ❌ NOT significant (p=0.6517 ≥ 0.05) — No significant billing difference.
# [ANOVA] Billing Amount across Medical Conditions
#   F-stat=2.2242  p=0.0490
#   ✅ SIGNIFICANT (p=0.0490 < 0.05) — Billing differs significantly by condition.
#
# [CHI-SQUARE] Gender vs Medical Condition
#   chi2=1.0721  p=0.9565  dof=5
#   ❌ NOT significant (p=0.9565 ≥ 0.05) — No significant relationship.
# [CHI-SQUARE] Blood Type vs Medical Condition
#   chi2=34.8181  p=0.4769  dof=35
#   ❌ NOT significant (p=0.4769 ≥ 0.05) — No significant relationship.
# [MANN-WHITNEY U] Billing — Male vs Female
#   U=379829549.0  p=0.2429
#   ❌ NOT significant (p=0.2429 ≥ 0.05) — No significant billing difference by gender.
#
# ══════════════════════════════════════════════════════════════════════
#   CORRELATION ANALYSIS
# ══════════════════════════════════════════════════════════════════════
#
# ── Pearson Correlations ──
#   Age                       vs Billing Amount             r=-0.0034  p=0.4218  ❌ Not significant
#   Age                       vs Days_in_Hospital           r=+0.0079  p=0.0644  ❌ Not significant
#   Billing Amount            vs Days_in_Hospital           r=-0.0049  p=0.2515  ❌ Not significant
#
# ── Spearman Correlations ──
#   Age                       vs Billing Amount             rho=-0.0033  p=0.4456  ❌ Not significant
#   Age                       vs Days_in_Hospital           rho=+0.0079  p=0.0635  ❌ Not significant
#   Billing Amount            vs Days_in_Hospital           rho=-0.0048  p=0.2559  ❌ Not significant
# [21:26:17] INFO — stats:   Saved → correlation_key_features.png
# [21:26:18] INFO — stats:   Saved → billing_outlier_boxplot.png
# [21:26:21] INFO — stats:   Saved → dist_age.png
# [21:26:24] INFO — stats:   Saved → dist_billing_amount.png
# [21:26:26] INFO — stats:   Saved → dist_days_in_hospital.png
# ✅ Statistical analysis complete!

# %% [markdown]
# ## Interpretation of Results
# - **p < 0.05**: Indicates a statistically significant result, meaning the observed difference or relationship is unlikely to have occurred by chance.
# - **p >= 0.05**: Indicates no statistically significant result.
