# %% [markdown]
# # Machine Learning & Predictions
#
# This notebook trains three models:
# 1. **Billing Amount Predictor** (Regression)
# 2. **Readmission Risk Classifier** (Classification)
# 3. **Patient Clustering** (Unsupervised)

# %%
import sys; sys.path.insert(0, '../')
from src.ml_models import run_ml_models
from IPython.display import display, Image
import glob
import os

# Train models
run_ml_models()
# Out:
# ══════════════════════════════════════════════════════════════════════
#   MODEL 1 — BILLING AMOUNT PREDICTOR (Regression)
# ══════════════════════════════════════════════════════════════════════
# [21:27:28] INFO — ml:   Linear Regression          MAE=$12,369  RMSE=$14,272  R²=-0.0001
# [21:27:49] INFO — ml:   Random Forest              MAE=$12,306  RMSE=$14,470  R²=-0.0281
# [21:28:02] INFO — ml:   Gradient Boosting          MAE=$12,384  RMSE=$14,287  R²=-0.0021
# ── Model Comparison Table ──
# Model                             MAE        RMSE        R²
# ────────────────────────────────────────────────────────────
#   Linear Regression        $   12,369  $   14,272   -0.0001
#   Random Forest            $   12,306  $   14,470   -0.0281
#   Gradient Boosting        $   12,384  $   14,287   -0.0021
#
#   🏆 Best model: Linear Regression (R²=-0.0001)
# [21:28:02] INFO — ml:   Saved → models/billing_predictor.pkl
# [21:28:03] INFO — ml:   Saved → m1_actual_vs_predicted.png
# ══════════════════════════════════════════════════════════════════════
#   MODEL 2 — READMISSION RISK CLASSIFIER (Classification)
# ══════════════════════════════════════════════════════════════════════
# [21:28:07] INFO — ml:   Logistic Regression     Acc=0.671  F1=0.000  AUC=0.497
# [21:28:13] INFO — ml:   Random Forest           Acc=0.681  F1=0.291  AUC=0.603
# [21:28:15] INFO — ml:   XGBoost                 Acc=0.662  F1=0.097  AUC=0.524
# ── Classifier Comparison ──
# Model                      Acc    Prec     Rec      F1     AUC
# ──────────────────────────────────────────────────────────────
#   Logistic Regression   0.671  0.000  0.000  0.000  0.497
#   Random Forest         0.681  0.543  0.199  0.291  0.603
#   XGBoost               0.662  0.405  0.055  0.097  0.524
#
#   🏆 Best model: Random Forest (F1=0.2908)
#
# ── Classification Report (best model) ──
#                precision    recall  f1-score   support
#
# Non-Emergency       0.70      0.92      0.79      7373
#     Emergency       0.54      0.20      0.29      3621
#
#      accuracy                           0.68     10994
#     macro avg       0.62      0.56      0.54     10994
#  weighted avg       0.65      0.68      0.63     10994
# [21:28:16] INFO — ml:   Saved → models/risk_classifier.pkl
# [21:28:16] INFO — ml:   Saved → m2_confusion_matrix.png
# [21:28:17] INFO — ml:   Saved → m2_roc_curves.png
# ══════════════════════════════════════════════════════════════════════
#   MODEL 3 — PATIENT CLUSTERING (KMeans k=4)
# ══════════════════════════════════════════════════════════════════════
# [21:28:41] INFO — ml:   Saved → m3_elbow_method.png
# ── Cluster Summary ──
#                  Age  Billing Amount  Days_in_Hospital  Risk_Score  Count
# Cluster_Label
# Critical       51.74        36389.30             23.64        2.95  13470
# High Risk      51.58        36524.03              7.40        2.93  13530
# Low Risk       69.91        14954.45             15.63        1.23  13887
# Medium Risk    33.17        15062.29             15.37        1.24  14079
# [21:28:47] INFO — ml:   Saved → m3_pca_scatter.png
# [21:28:47] INFO — ml:   Saved → m3_cluster_age.png
# [21:28:47] INFO — ml:   Saved → m3_cluster_billing_amount.png
# [21:28:48] INFO — ml:   Saved → m3_cluster_days_in_hospital.png
# [21:28:48] INFO — ml:   Saved → m3_cluster_risk_score.png
# [21:28:48] INFO — ml:   Saved → models/cluster_model.pkl
# ✅ All ML models complete!

# %% [markdown]
# ## Model Visualizations

# %%
chart_files = sorted(glob.glob('../charts/ml/*.png'))
for file in chart_files:
    display(Image(filename=file))
    print(f'Chart: {os.path.basename(file)}\n')
# Out:
# Chart: m1_actual_vs_predicted.png
# Chart: m2_confusion_matrix.png
# Chart: m2_roc_curves.png
# Chart: m3_cluster_age.png
# Chart: m3_cluster_billing_amount.png
# Chart: m3_cluster_days_in_hospital.png
# Chart: m3_cluster_risk_score.png
# Chart: m3_elbow_method.png
# Chart: m3_pca_scatter.png
