# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook loads the cleaned dataset and runs the EDA pipeline, generating and displaying 23 charts with their interpretations.

# %%
import sys; sys.path.insert(0, '../')
from src.eda import run_eda
from IPython.display import display, Image
import os

# Generate charts
run_eda()
# Out:
# ══════════════════════════════════════════════════════════════════════
#   EDA — GENERATING ALL 23 CHARTS
# ══════════════════════════════════════════════════════════════════════
# [21:43:59] INFO — eda: Chart 01/23 — chart01
# [21:44:00] INFO — eda:   Saved → 01_age_distribution.png
# [21:44:00] INFO — eda: Chart 02/23 — chart02
# [21:44:00] INFO — eda:   Saved → 02_gender_pie.png
# [21:44:00] INFO — eda: Chart 03/23 — chart03
# [21:44:01] INFO — eda:   Saved → 03_blood_type.png
# [21:44:01] INFO — eda: Chart 04/23 — chart04
# [21:44:01] INFO — eda:   Saved → 04_age_group.png
# [21:44:01] INFO — eda: Chart 05/23 — chart05
# [21:44:02] INFO — eda:   Saved → 05_gender_age_group.png
# [21:44:02] INFO — eda: Chart 06/23 — chart06
# [21:44:02] INFO — eda:   Saved → 06_top_conditions.png
# [21:44:02] INFO — eda: Chart 07/23 — chart07
# [21:44:02] INFO — eda:   Saved → 07_condition_admission_stacked.png
# [21:44:02] INFO — eda: Chart 08/23 — chart08
# [21:44:03] INFO — eda:   Saved → 08_test_results_donut.png
# [21:44:03] INFO — eda: Chart 09/23 — chart09
# [21:44:03] INFO — eda:   Saved → 09_medication.png
# [21:44:03] INFO — eda: Chart 10/23 — chart10
# [21:44:03] INFO — eda:   Saved → 10_condition_test_heatmap.png
# [21:44:03] INFO — eda: Chart 11/23 — chart11
# [21:44:04] INFO — eda:   Saved → 11_top_hospitals.png
# [21:44:04] INFO — eda: Chart 12/23 — chart12
# [21:44:04] INFO — eda:   Saved → 12_top_doctors.png
# [21:44:04] INFO — eda: Chart 13/23 — chart13
# [21:44:04] INFO — eda:   Saved → 13_avg_billing_hospital.png
# [21:44:04] INFO — eda: Chart 14/23 — chart14
# [21:44:05] INFO — eda:   Saved → 14_days_hospital_boxplot.png
# [21:44:05] INFO — eda: Chart 15/23 — chart15
# [21:44:06] INFO — eda:   Saved → 15_billing_histogram.png
# [21:44:06] INFO — eda: Chart 16/23 — chart16
# [21:44:07] INFO — eda:   Saved → 16_billing_insurance_boxplot.png
# [21:44:07] INFO — eda: Chart 17/23 — chart17
# [21:44:07] INFO — eda:   Saved → 17_billing_admission_violin.png
# [21:44:07] INFO — eda: Chart 18/23 — chart18
# [21:44:07] INFO — eda:   Saved → 18_monthly_revenue.png
# [21:44:07] INFO — eda: Chart 19/23 — chart19
# [21:44:08] INFO — eda:   Saved → 19_revenue_by_condition.png
# [21:44:08] INFO — eda: Chart 20/23 — chart20
# [21:44:08] INFO — eda:   Saved → 20_billing_category_pie.png
# [21:44:08] INFO — eda: Chart 21/23 — chart21
# [21:44:09] INFO — eda:   Saved → 21_correlation_heatmap.png
# [21:44:09] INFO — eda: Chart 22/23 — chart22
# [21:44:11] INFO — eda:   Saved → 22_age_vs_billing_scatter.png
# [21:44:11] INFO — eda: Chart 23/23 — chart23
# [21:44:13] INFO — eda:   Saved → 23_days_vs_billing_scatter.png
# ✅ EDA complete! 23 charts saved to C:\Users\lenvo\Downloads\HEALTHCARE PROJECT\charts\eda

# %% [markdown]
# ## Generated Charts
# The charts are saved in the `charts/eda/` directory. Below we display a selection of them.

# %%
import glob
chart_files = sorted(glob.glob('../charts/eda/*.png'))
for file in chart_files:
    display(Image(filename=file))
    print(f'Chart: {os.path.basename(file)}\n')
# Out:
# Chart: 01_age_distribution.png
# Chart: 02_gender_pie.png
# Chart: 03_blood_type.png
# Chart: 04_age_group.png
# Chart: 05_gender_age_group.png
# Chart: 06_top_conditions.png
# Chart: 07_condition_admission_stacked.png
# Chart: 08_test_results_donut.png
# Chart: 09_medication.png
# Chart: 10_condition_test_heatmap.png
# Chart: 11_top_hospitals.png
# Chart: 12_top_doctors.png
# Chart: 13_avg_billing_hospital.png
# Chart: 14_days_hospital_boxplot.png
# Chart: 15_billing_histogram.png
# Chart: 16_billing_insurance_boxplot.png
# Chart: 17_billing_admission_violin.png
# Chart: 18_monthly_revenue.png
# Chart: 19_revenue_by_condition.png
# Chart: 20_billing_category_pie.png
# Chart: 21_correlation_heatmap.png
# Chart: 22_age_vs_billing_scatter.png
# Chart: 23_days_vs_billing_scatter.png
